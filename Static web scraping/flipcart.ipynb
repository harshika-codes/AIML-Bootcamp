# %% [markdown]
# <div style="
# background: linear-gradient(135deg, #f5e6d3, #e7c9a9);
# padding:35px;
# border-radius:20px;
# text-align:center;
# ">
#
# <h1 style="
# color:#6b4423;
# font-size:55px;
# font-family:Consolas;
# font-weight:bold;
# margin:0;
# letter-spacing:3px;
# ">
# 🕸️ WEB SCRAPING
# </h1>
#
# </div>

# %% [markdown]
# <div style="
# background: linear-gradient(135deg, #f3e8ff, #ddd6fe);
# padding:20px;
# border-radius:15px;
# text-align:center;
# box-shadow:0 3px 8px rgba(0,0,0,0.1);
# margin:auto;
# ">
#
# <h2 style="
# margin:0;
# font-family:Consolas;
# font-size:32px;
# font-weight:bold;
# color:#5b21b6;
# ">
# 🎯 TARGET WEBSITE = FLIPCART
# </h2>
#
# </div>

# %% [markdown]
# <h3 style="
# background:#1e293b;
# color:white;
# padding:12px 20px;
# border-radius:8px;
# font-family:Consolas;
# text-align:left;
# ">
# 📌 Project Overview
# </h3>

# %% [markdown]
# **This project is based on Web Scraping using Python, where data is extracted from an e-commerce website (Flipkart) to analyze product information.**
#
# Web scraping is an automated technique used to collect large amounts of data from websites. In this project, we extract details of shoes listed on Flipkart such as product name, price, rating, and brand using libraries like BeautifulSoup and Requests.
#
# The main objective of this project is to demonstrate how structured data can be collected from unstructured web pages and converted into a usable format for analysis.
#
# **This scraped data can further be used for:**
#
# Price comparison
# Market analysis
# Trend identification
# Data visualization
#
# However, websites like Flipkart load dynamic content, so scraping requires careful handling of HTML structure and selectors.
#
# **This project helps in understanding real-world applications of:**
#
# Python programming
# Web data extraction
# HTML parsing
# Data collection for analytics

# %% [markdown]
# <div style="
# background: #1f1f1f;
# color: white;
# padding: 10px 20px;
# border-radius: 8px;
# display: inline-block;
# font-family: Arial;
# font-size: 20px;
# font-weight: 600;
# ">
# Importing Liberaries
# </div>

# %%
import pandas as pd

# %% [markdown]
# <div style="
# background: #1f1f1f;
# color: white;
# padding: 10px 20px;
# border-radius: 8px;
# display: inline-block;
# font-family: Arial;
# font-size: 20px;
# font-weight: 600;
# ">
# Extraction of Content
# </div>

# %%
import requests
url = "https://www.flipkart.com/search?q=shoes&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_2_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_2_0_na_na_na&as-pos=2&as-type=TRENDING&suggestionId=shoes&requestId=137bfca7-eb1c-4aa8-8ce9-79a525bf0eb2"
response = requests.get(url)

# %% [markdown]
# <div style="
# background: #1f1f1f;
# color: white;
# padding: 10px 20px;
# border-radius: 8px;
# display: inline-block;
# font-family: Arial;
# font-size: 20px;
# font-weight: 600;
# ">
# Checking the Status code
# </div>

# %%
print(response.status_code)
# Out:
# 403

# %%
header = {
    'User-Agent' : 'Mozilla/5.0(Windows NT 10.0; Win64; x64)aAppleWebKit/537.36 (KHTML, like Gecko)Chrome/91.0.4472.124 Safari/537.36'
}
response = requests.get(url, headers=header)

# %%
print(response.status_code)
# Out:
# 200

# %% [markdown]
# <div style="
# background: #1f1f1f;
# color: white;
# padding: 10px 20px;
# border-radius: 8px;
# display: inline-block;
# font-family: Arial;
# font-size: 20px;
# font-weight: 600;
# ">
# Parsing the Content
# </div>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.aa1465.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.fbaef9.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %%
soup3 = soup.find_all('div', class_="nZIRY7")
soup3
# Out:
# [<div class="nZIRY7"><div data-id="SHOH8PFQYHYQVD24" style="width:25%"><div class="bLCLBY nr15la"><a class="CIaYa1" href="/nobelite-premium-sports-gym-trending-stylish-running-shoes-men/p/itm33552770b6111?pid=SHOH8PFQYHYQVD24&amp;lid=LSTSHOH8PFQYHYQVD24SH5X43&amp;marketplace=FLIPKART&amp;q=shoes&amp;store=osp&amp;srno=s_1_1&amp;otracker=AS_Query_TrendingAutoSuggest_2_0_na_na_na&amp;otracker1=AS_Query_TrendingAutoSuggest_2_0_na_na_na&amp;fm=organic&amp;iid=en_z24ogd7OPWZCVfnG5zjrT2fEIJ8OLp8t-gbtB6_l3wq_HN_Blbhml1c6s0cMNSRR-N4eWn5bgkuskCLb41n55qy2ue7K_QlmAJg0rU8Yt7_W_uWnsq8UAzTUHKK9Kuth&amp;ppt=None&amp;ppn=None&amp;ssid=grri2t5tbk0000001782273702903&amp;qH=b0a8b6f820479900&amp;ov_redirect=true" rel="noopener noreferrer" target="_blank"><div><div><div class="jn1d30" style="padding-top:120.00%"><div class="fWB4Ui TTHoOY" style="padding-top:120.00%"><img alt="" class="MZeksS" src="https://rukminim2.flixcart.com/image/612/612/xif0q/shoe/f/1/e/-original-imahh6w5z8wqb67p.jpeg?q=70"/></div><
# ...

# %% [markdown]
# <div style="
# background: #1f1f1f;
# color: white;
# padding: 10px 20px;
# border-radius: 8px;
# display: inline-block;
# font-family: Arial;
# font-size: 20px;
# font-weight: 600;
# ">
# Fetch The Data
# </div>

# %%
soup3 =[]

# %%
shoes = soup.find_all('div', class_='nZIRY7')
for i in shoes:

    name = i.find('div', class_='Fo1I0b').text.strip()

    price = i.find('div', class_='hZ3P6w').get_text(strip=True)

    off = i.find('div', class_='HQe8jr').get_text(strip=True)

    discount = i.find('div', class_='kRYCnD').get_text(strip=True)
    


    soup3.append({
        'Name': name,
        'Price': price,
        'Off': off,
        'Discount': discount
        
    })

soup3
# Out:
# [{'Name': 'NOBELITE', 'Price': '₹379', 'Off': '84% off', 'Discount': '₹2,499'},
#  {'Name': 'CLYMB', 'Price': '₹448', 'Off': '82% off', 'Discount': '₹2,499'},
#  {'Name': 'Echor', 'Price': '₹395', 'Off': '80% off', 'Discount': '₹1,999'},
#  {'Name': 'Echor', 'Price': '₹417', 'Off': '79% off', 'Discount': '₹1,999'},
#  {'Name': 'HOTSTYLE', 'Price': '₹229', 'Off': '77% off', 'Discount': '₹999'},
#  {'Name': 'Layasa', 'Price': '₹434', 'Off': '56% off', 'Discount': '₹999'},
#  {'Name': 'asian', 'Price': '₹337', 'Off': '66% off', 'Discount': '₹999'},
#  {'Name': 'Shoe Island',
#   'Price': '₹448',
#   'Off': '55% off',
#   'Discount': '₹999'},
#  {'Name': 'ADIDAS', 'Price': '₹1,461', 'Off': '68% off', 'Discount': '₹4,599'},
#  {'Name': 'corsac', 'Price': '₹405', 'Off': '79% off', 'Discount': '₹1,999'}]

# %%
soup3
# Out:
# [{'Name': 'NOBELITE', 'Price': '₹379', 'Off': '84% off', 'Discount': '₹2,499'},
#  {'Name': 'CLYMB', 'Price': '₹448', 'Off': '82% off', 'Discount': '₹2,499'},
#  {'Name': 'Echor', 'Price': '₹395', 'Off': '80% off', 'Discount': '₹1,999'},
#  {'Name': 'Echor', 'Price': '₹417', 'Off': '79% off', 'Discount': '₹1,999'},
#  {'Name': 'HOTSTYLE', 'Price': '₹229', 'Off': '77% off', 'Discount': '₹999'},
#  {'Name': 'Layasa', 'Price': '₹434', 'Off': '56% off', 'Discount': '₹999'},
#  {'Name': 'asian', 'Price': '₹337', 'Off': '66% off', 'Discount': '₹999'},
#  {'Name': 'Shoe Island',
#   'Price': '₹448',
#   'Off': '55% off',
#   'Discount': '₹999'},
#  {'Name': 'ADIDAS', 'Price': '₹1,461', 'Off': '68% off', 'Discount': '₹4,599'},
#  {'Name': 'corsac', 'Price': '₹405', 'Off': '79% off', 'Discount': '₹1,999'}]

# %%
df = pd.DataFrame(soup3)
df
# Out:
#           Name   Price      Off Discount
# 0     NOBELITE    ₹379  84% off   ₹2,499
# 1        CLYMB    ₹448  82% off   ₹2,499
# 2        Echor    ₹395  80% off   ₹1,999
# 3        Echor    ₹417  79% off   ₹1,999
# 4     HOTSTYLE    ₹229  77% off     ₹999
# 5       Layasa    ₹434  56% off     ₹999
# 6        asian    ₹337  66% off     ₹999
# 7  Shoe Island    ₹448  55% off     ₹999
# 8       ADIDAS  ₹1,461  68% off   ₹4,599
# 9       corsac    ₹405  79% off   ₹1,999

# %% [markdown]
# <div style="
# background: #1f1f1f;
# color: white;
# padding: 10px 20px;
# border-radius: 8px;
# display: inline-block;
# font-family: Arial;
# font-size: 20px;
# font-weight: 600;
# ">
# Save CSV File
# </div>

# %%
df.to_csv("soup3", index = False)

# %% [markdown]
# <div style="
# background:white;
# color:#111827;
# padding:25px;
# border-radius:15px;
# text-align:center;
# font-size:24px;
# font-weight:700;
# font-family:Segoe UI;
# border:2px solid #6366f1;
# box-shadow:0 6px 15px rgba(0,0,0,0.1);
# ">
# THANK YOU FOR VISITING 🚀
# </div>
