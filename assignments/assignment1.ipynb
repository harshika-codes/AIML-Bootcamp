# %% [markdown]
# <div style="background:#eef0f8;padding:15px 20px;border-left:6px solid #4a5cff;">
# <p style="margin:0;color:#4a5cff;font-size:12px;font-weight:bold;letter-spacing:4px;">
# SECTION 02
# </p>
#
# <h1 style="margin:8px 0 0 0;color:#1a2340;">
# Warm-Up Questions
# </h1>
# </div>

# %% [markdown]
# <div style="
# background:#fff8e6;
# padding:8px 12px;
# border-left:4px solid #f4b400;
# border-radius:5px;
# margin:10px 0;">
#
# <h3 style="margin:0;color:#b26a00;">
# 💬 Concept Recall Questions
# </h3>
#
# </div>

# %% [markdown]
# 1. What is the difference between == and is in Python? Give one example where they produce different results.</br>
# ans: == compares values and is compares memory location
#
# 2. Why does 0.1 + 0.2 == 0.3 return False ? What is the correct way to compare floats?</br>
# ans : it fails due to floating-point rounding errors; use math.isclose() to compare
#
# 4. What is a mutable default argument bug? How do you fix it?</br>
# abns : Using mutable defaults (like []) creates a bug; fix it by using None
#
# 5. What does and return when all values are truthy? What does or return when all values are falsy?</br>
# ans :all truthy returns last and all falsy return first.
#
#
# 6. What is the difference between // and / ? What does -7 // 2 return and why?</br>
# ans : / is float division, // rounds down; so -7 // 2 equals -4.
#
# 7. What does for-else do in Python? When does the else block run?</br>
# ans : The else block runs only if the loop completes without a break.
#
#
# 8. Why should you never use str += inside a loop? What should you use instead?</br>
# ans : str += inside loops creates new objects and slows code; use "".join()
#
#
# 9. What is the difference between a generator and a list comprehension?</br>
# ans :List comprehension stores everything in memory; generators yield items one-by-one

# %% [markdown]
# <div style="
# background:#fff8e6;
# padding:8px 12px;
# border-left:4px solid #f4b400;
# border-radius:5px;
# margin:10px 0;">
#
# <h3 style="margin:0;color:#b26a00;">
# ⚡ Rapid-Fire Round
# </h3>
#
# </div>

# %% [markdown]
# **ANSWERS**
# 1.Type(true) -> bool</br>
# 2. bool is int subclass -> true</br>
# 3. true+true+true -> true</br>
# 4. walrus operator -> python 3.8</br>
# 7. id() -> location</br>
# 8. falsy values -> none , empty string , 0</br>
# 9.  membership operator -> whether a string is present or not</br>

# %% [markdown]
# <div style="
# background:#fff8e6;
# padding:8px 12px;
# border-left:4px solid #f4b400;
# border-radius:5px;
# margin:10px 0;">
#
# <h3 style="margin:0;color:#b26a00;">
# 📝 Fill in the Blanks
# </h3>
#
# </div>

# %%
#1. abs(a - b) < 1e-9) 
a = 0.1 + 0.2
b = 0.3
print(abs(a - b) < 1e-9)
# Out:
# True

# %%
#2. a, b = b, a
a = 10
b = 20
def average(numbers):
    if numbers is None:
        raise TypeError("Input cannot be None")

    if len(numbers) == 0:
        return None

    for num in numbers:
        if num is None:
            raise TypeError("List contains None value")
        if not isinstance(num, (int, float)):
            raise TypeError("All elements must be numbers")

    return sum(numbers) / len(numbers)


try:
    print(average([]))
except Exception as e:
    print(e)

try:
    print(average([5]))
except Exception as e:
    print(e)

try:
    print(average(None))
except Exception as e:
    print(e)

try:
    print(average(["a", "b"]))
except Exception as e:
    print(e)

try:
    print(average([1, 2, None, 4]))
except Exception as e:
    print(e)
a, b = b, a
print("a =", a)
print("b =", b)
# Out:
# None
# 5.0
# Input cannot be None
# All elements must be numbers
# List contains None value
# a = 20
# b = 10

# %%
#3. if result ____is____ None:
result = None

if result is None:
    print("Result is None")
else:
    print("Result is not None")
# Out:
# Result is None

# %%
#5. result = "".join(words)
words = ["Hello", "World", "Python"]
result = "".join(words)
print(result)
# Out:
# HelloWorldPython

# %%
#6. while ___chunk_____ := f.read(1024):
# process(chunk)
from io import StringIO

f = StringIO("HelloPython")

while (chunk := f.read(4)):
    print(chunk)
# Out:
# Hell
# oPyt
# hon

# %%
# 8 Floor division of -9 by 2 equals: _-5_______
result = -9 // 2
print(result)

# 9. To get both index andef average(numbers):
#for i, v in ___enumerate_____(my_list):
my_list = ["Apple", "Banana", "Mango"]
for i, v in enumerate(my_list):
    print(i, v)

# 10. 'and' returns the _first_______ falsy value, or the __last______ value if all truthy.
print(5 and 10 and 20)      # Last value
print(5 and 0 and 20)       # First falsy value
# Out:
# -5
# 0 Apple
# 1 Banana
# 2 Mango
# 20
# 0

# %% [markdown]
# <div style="background:#eef0f8;padding:15px 20px;border-left:6px solid #4a5cff;">
# <p style="margin:0;color:#4a5cff;font-size:12px;font-weight:bold;letter-spacing:4px;">
# SECTION 03
# </p>
#
# <h1 style="margin:8px 0 0 0;color:#1a2340;">
# Predict the Output
# </h1>
# </div>

# %% [markdown]
# **EASY**

# %%
# E1 — Your prediction: 3, 1 , 3.3
x = 10
y = 3
print(x // y)
print(x % y)
print(x / y)
# Out:
# 3
# 1
# 3.3333333333333335

# %%
# E2 — Your prediction: @LICE
name = " Alice "
print(name.strip().upper().replace('A', '@'))
# Out:
# @LICE

# %%
# E3 — Your prediction: __TRUE_________
a = [1, 2, 3]
b = a
b.append(4)
print(a)
print(a is b)
# Out:
# [1, 2, 3, 4]
# True

# %%
# E4 — Your prediction: _ false , true , true , true , false__________
print(bool(""), bool(" "), bool(0), bool([0]), bool(None))
# Out:
# False True False True False

# %% [markdown]
# **INTERMEDIATE**

# %%
# I1 — Your prediction: ___________
print(0 and "hello") # Your prediction: ___0_______
print("" or "default") # Your prediction: __"default"_________
print(None or [] or 0) #Your prediction: __0_________
print("a" and "b" and "c") # Your prediction: __c_________
# Out:
# 0
# default
# 0
# c

# %%
# I2 — Your prediction: __positive , negative_________
x = 5
result = "positive" if x > 0 else "negative" if x < 0 else "zero"
print(result)
y = -3
result2 = "positive" if y > 0 else "negative" if y < 0 else "zero"
print(result2)
# Out:
# positive
# negative

# %%
# I3 — Your prediction: _ World ; !dlrow ,olleH ;  __Hlo ol!________
s = "Hello, World!"
print(s[7:12])
print(s[::-1])
print(s[::2])
# Out:
# World
# !dlroW ,olleH
# Hlo ol!

# %%
# I4 — Your prediction: _8 , 9, 20__________
def f(x, multiplier=2):
 return x * multiplier
print(f(3))
print(f(3, 3))
print(f(multiplier=5, x=4))
# Out:
# 6
# 9
# 20

# %% [markdown]
# **TOUGH**

# %%
# T1 — Your prediction: __-4 , 1 , -4 , -1_________
print(-7 // 2)
print(-7 % 2)
print(7 // -2)
print(7 % -2)
# Out:
# -4
# 1
# -4
# -1

# %%
# T2 — Your prediction: __512, 64_________
print(2 ** 3 ** 2) # right-associative exponentiation
print((2 ** 3) ** 2)
# Out:
# 512
# 64

# %%
# T3 — Your prediction: __no idea_________
def add_tag(item, tags=[]):
 tags.append(item)
 return tags
print(add_tag("python"))
print(add_tag("ml"))
print(add_tag("ai"))
# Out:
# ['python']
# ['python', 'ml']
# ['python', 'ml', 'ai']

# %%
# T4 — Your prediction: __2,3,2_________
funcs = []
for i in range(3):
 funcs.append(lambda: i)
print([f() for f in funcs])
# Out:
# [2, 2, 2]

# %% [markdown]
# **HIDDEN**

# %%
# H1 — Integer caching: Your prediction: _true , true__________
a = 256
b = 256
print(a is b)
c = 257
d = 257
print(c is d)
# Out:
# True
# False

# %%
# H2 — Boolean arithmetic: Your prediction: _2 , 10, 3, 1 0__________
print(True + True)
print(True * 10)
print(sum([True, False, True, True, False]))
print(int(True), int(False))
# Out:
# 2
# 10
# 3
# 1 0

# %%
# H3 — for-else: Your prediction: _All even , found odd__________
for n in [2, 4, 6, 8]:
 if n % 2 != 0:
   print("Found odd")
   break
else:
   print("All even")
for n in [2, 3, 6, 8]:
   if n % 2 != 0:
    print("Found odd")
    break
else:
    print("All even")
# Out:
# All even
# Found odd

# %% [markdown]
# <div style="background:#eef0f8;padding:15px 20px;border-left:6px solid #4a5cff;">
# <p style="margin:0;color:#4a5cff;font-size:12px;font-weight:bold;letter-spacing:4px;">
# SECTION 04
# </p>
#
# <h1 style="margin:8px 0 0 0;color:#1a2340;">
# Debugging Challenge Zone
# </h1>
# </div>

# %%
# SYN-1: Find and fix all syntax errors
def greet(name) :
 message = f"Hello, {name}!"
 return message
# Your fix below: ):

# %%
# SYN-2: This code has 2 syntax errors
for i in range(5):
 if i% 2== 0:
   print(i, "is even")
# Your fix below: for i in range(5):
                  i%2==0:
# Out:
#   Cell In[23], line 6
#     i%2==0:
#     ^
# IndentationError: unexpected indent

# %%
# LOG-1: 
# Intent: 2% fee, minimum ₹5, maximum ₹200
def calculate_fee(amount):
 fee = amount * 2 / 100
 if fee < 5:
   fee = 5 # BUG: What is wrong here?
   if fee > 200:
    fee = 200 # BUG: And here?
 return fee
 print(calculate_fee(100)) # Expected: 5 (minimum applies)
print(calculate_fee(5000)) # Expected: 100
print(calculate_fee(15000)) # Expected: 200 (maximum applies)
# Identify bugs:
# Bug 1: fee==5
# Bug 2:fee == 200
# Your fix:== into =
# Out:
# 100.0
# 300.0

# %%
# LOG-2: Grade classifier — why does it always print "F"?
def classify_grade(score):
 if score >= 90:
  grade = "A"
 elif score >= 80:
  grade = "B"
 elif score >= 70:
  grade = "C"
 elif score >= 60:
     grade = "D"
 else:
  grade = "F" # BUG: Where is the error?
 return grade
print(classify_grade(95)) # Should be A
print(classify_grade(75)) # Should be C
print(classify_grade(45)) # Should be F
# Explanation:indentation after if elif and use of else and :
# Your fix: indentation and else:
# Out:
# A
# C
# F

# %%
# LOG-3: Count vowels function — returns wrong count
def count_vowels(text):
 count = 0
 for char in text:
  if char.lower() in "aeiou": # BUG: What's missing?
   count += 1
 return count
print(count_vowels("Hello World")) # Expected: 3
print(count_vowels("APPLE")) # Expected: 2
# Explanation:code read only lower case vowels that's why APPLE ans is wrong
# Your fix:char.lower()
# Out:
# 3
# 2

# %%
# RT-1: What error does this raise? Fix it.
def divide(a, b):
 return a / b
results = [divide(x,10) for x in [2, 5, 0, 1]]
print(results)
# Error type:mathematical error
# Your fix :(10,x) to (x,10)
# Out:
# [0.2, 0.5, 0.0, 0.1]

# %%
# RT-2: What error does this raise? Fix it.
data = {"name": "Alice", "age": 25}
print(f"Name: {data['name']}, Score: {data['score']}")
# Error type:
# Your fix (use .get() with a default):no idea
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 3
#       1 # RT-2: What error does this raise? Fix it.
#       2 data = {"name": "Alice", "age": 25}
# ----> 3 print(f"Name: {data['name']}, Score: {data['score']}")
#       4 # Error type:
#       5 # Your fix (use .get() with a default):no idea
#
# KeyError: 'score'

# %%
# RT-3: UnboundLocalError — explain why and fix it
counter = 0
def increment():
    global counter
    counter += 1 # BUG: Why does this fail?
    return counter
print(increment())
# Explanation:inside function the counter id global 
# Your fix (two solutions: global keyword OR return value approach):global counter , print increment

# %%
# HIDDEN-1: 
# Intent: Remove all negative numbers from the list
numbers = [1, -2, 3, -4, 5, -6, 7]
for num in numbers[:]:
 if num < 0:
  numbers.remove(num)
print(numbers)
# What do you get? What should you get?  [1, 3, 5, 7] 
# Why does it fail?  Modifying a list while iterating over it causes elements to be skipped.
# Your fix:numbers = [1, -2, 3, -4, 5, -6, 7]
#          numbers = [num for num in numbers if num >= 0]
#           print(numbers)

# %% [markdown]
# <div style="background:#eef0f8;padding:15px 20px;border-left:6px solid #4a5cff;">
# <p style="margin:0;color:#4a5cff;font-size:12px;font-weight:bold;letter-spacing:4px;">
# SECTION 05
# </p>
#
# <h1 style="margin:8px 0 0 0;color:#1a2340;">
# Edge cases & Hidden Scenerios
# </h1>
# </div>

# %%
# EC-1: 
# The function below works for normal input — make it handle all edge cases
def average(numbers):
 """Return the average of a list of numbers."""
 return sum(numbers) / len(numbers)
# Test cases to handle:
# average([]) → should return None or raise a clear ValueError
# average([5]) → should return 5.0
# average(None) → should raise TypeError with clear message
# average(["a", "b"]) → should raise TypeError
# average([1, 2, None, 4]) → handle None in list
# Your improved version:
def average(numbers):
    if numbers is None:
        return "Input cannot be None"

    if len(numbers) == 0:
        return None

    for i in numbers:
        if i is None:
            return "List contains None value"
        if not isinstance(i, (int, float)):
            return "All elements must be numbers"

    return sum(numbers) / len(numbers)


print(average([]))
print(average([5]))
print(average(None))
print(average(["a", "b"]))
print(average([1, 2, None, 4]))

# %%
# EC-2: 
# Check if a password meets requirements:
# Length: 8-20 chars, has uppercase, lowercase, digit, special char
 # Test these boundaries:
 # "" → False (empty)
 # "abc" → False (too short)
 # "a" * 21 → False (too long)
 # "Abcdefg1!" → True
 # "ABCDEFG1!" → False (no lowercase)
 # "abcdefg1!" → False (no uppercase)
 # "Abcdefgh!" → False (no digit)
 # "Abcdefg12" → False (no special char)
 # Your implementation:
def is_valid_password(pwd):
    if len(pwd) < 8 or len(pwd) > 20:
        return False

    has_upper = False
    has_lower = False
    has_digit = False
    has_special = False

    for ch in pwd:
        if ch.isupper():
            has_upper = True
        elif ch.islower():
            has_lower = True
        elif ch.isdigit():
            has_digit = True
        else:
            has_special = True

    return has_upper and has_lower and has_digit and has_special


# Test Cases
print(is_valid_password(""))            
print(is_valid_password("abc"))         
print(is_valid_password("a" * 21))      
print(is_valid_password("Abcdefg1!"))   
print(is_valid_password("ABCDEFG1!"))   
print(is_valid_password("abcdefg1!"))   
print(is_valid_password("Abcdefgh!"))   
print(is_valid_password("Abcdefg12"))

# %% [markdown]
# <div style="background:#eef0f8;padding:15px 20px;border-left:6px solid #4a5cff;">
# <p style="margin:0;color:#4a5cff;font-size:12px;font-weight:bold;letter-spacing:4px;">
# SECTION 07
# </p>
#
# <h1 style="margin:8px 0 0 0;color:#1a2340;">
# Think Like an Engineering
# </h1>
# </div>

# %% [markdown]
# **Scenario A:**
# A function get_user_data(user_id) fetches a user's data from a database and returns a dict.</br>
# 1. What could go wrong? List at least 5 failure modes.</br>
# **ANS :** 1. Database connection fails.</br>
#     2. Query execution times out.</br>
#     3. Returned data is incomplete or corrupted.</br>
#     4. Network issues between application and database.</br>
#     5. Database server is overloaded.</br>
#     </br>
# 2. What assumptions is the current design making?</br>
# **ANS :** 1. Database is always available. </br>
#        2. User record exists.</br>
#        3. Returned data is in the correct format (dictionary).</br>
#        4.Network connectivity is stable.</br>
#        5.Queries execute successfully without errors.</br>
#         </br>
# 3. How would you validate inputs before the DB call?</br>
# **ANS :**  1. Check that user_id is not None.</br>
#        2. Verify that user_id has the correct data type (e.g., integer).</br>
#        3. Ensure user_id is positive.</br>
#        4.Reject empty or invalid values.</br>
#        5. Sanitize inputs to prevent injection attacks.</br>
#  EXAMPLE :    if not isinstance(user_id, int) or user_id <= 0:</br>
#                  raise ValueError("Invalid user_id")</br>
#
# 5. How would this behave at scale? (1 million calls/hour)</br>
# **Ans :**  At 1 million calls per hour, the database may experience heavy load, causing slower response times and possible timeouts.
#       Scaling techniques like caching and load balancing would be needed.</br>
#    </br>
# 6. What business impact could failures cause?</br>
# **Ans :**  Failures can prevent users from accessing their data, leading to poor user experience and customer dissatisfaction.
#        They may also cause revenue loss and damage the company's reputation.</br>

# %% [markdown]
# **Scenario B**: A loop processes 10,000 order records. For each order, it builds a report string using += .</br>
# 1. What is the time complexity of string += in a loop? Why?</br>
# **ans : String += in a loop has O(n²) time complexity because strings are immutable, so a new string is created and copied on each concatenation.** </br>
# 2. How much memory could this consume for 10,000 records of 1KB each?</br>
# **ans : The final report would be about 10 MB (10,000 × 1 KB), but temporary string copies can consume much more memory during processing.** </br>
# 3. What is the correct approach?</br>
# **ans : Store strings in a list and use "".join(list) at the end, which is more efficient in both time and memory.** </br>
# 4. How would you test that your fix actually improved performance?</br>
# **ans : Measure execution time and memory usage of both versions using benchmarking tools such as timeit and compare the results on the same dataset.** </br>

# %% [markdown]
# <div style="background:#eef0f8;padding:15px 20px;border-left:6px solid #4a5cff;">
# <p style="margin:0;color:#4a5cff;font-size:12px;font-weight:bold;letter-spacing:4px;">
# SECTION 08
# </p>
#
# <h1 style="margin:8px 0 0 0;color:#1a2340;">
# Hands On Coding Practices
# </h1>
# </div>

# %%
# B1: Write a function that takes a temperature in Celsius and returns it in
# Fahrenheit AND Kelvin. Return as a tuple: (fahrenheit, kelvin)
# Formula: F = (C × 9/5) + 32 | K = C + 273.15
# B1: Celsius → Fahrenheit and Kelvin

def convert_temperature(celsius):
    fahrenheit = (celsius * 9/5) + 32
    kelvin = celsius + 273.15
    return (fahrenheit, kelvin)

# Tests:
assert convert_temperature(0) == (32.0, 273.15)
assert convert_temperature(100) == (212.0, 373.15)

print("B1 passed ")
# Out:
# B1 passed

# %%
# B2: Write a function that checks if a string is a palindrome
# Ignore case and spaces
# "A man a plan a canal Panama" → True
# "hello" → False
def is_palindrome(text):
    # Remove spaces and convert to lowercase
    cleaned = text.replace(" ", "").lower()
    
    # Check reverse
    return cleaned == cleaned[::-1]

# Tests:
assert is_palindrome("racecar") == True
assert is_palindrome("hello") == False
assert is_palindrome("A man a plan a canal Panama") == True
assert is_palindrome("") == True

print("B2 passed ")
# Out:
# B2 passed

# %%
# B3: FizzBuzz (classic — but do it in ONE comprehension, not a loop)
# For numbers 1-30: "Fizz" if divisible by 3, "Buzz" if by 5,
# "FizzBuzz" if both, else the number itself
# B3: FizzBuzz using list comprehension

fizzbuzz = [
    "FizzBuzz" if i % 15 == 0
    else "Fizz" if i % 3 == 0
    else "Buzz" if i % 5 == 0
    else i
    for i in range(1, 31)
]

# Test:
assert fizzbuzz[2] == "Fizz"       # 3
assert fizzbuzz[4] == "Buzz"       # 5
assert fizzbuzz[14] == "FizzBuzz"  # 15
assert fizzbuzz[6] == 7

print("B3 passed ", fizzbuzz[:15])
# Out:
# B3 passed  [1, 2, 'Fizz', 4, 'Buzz', 'Fizz', 7, 8, 'Fizz', 'Buzz', 11, 'Fizz', 13, 14, 'FizzBuzz']

# %% [markdown]
# <div style="background:#eef0f8;padding:15px 20px;border-left:6px solid #4a5cff;">
# <p style="margin:0;color:#4a5cff;font-size:12px;font-weight:bold;letter-spacing:4px;">
# SECTION 10
# </p>
#
# <h1 style="margin:8px 0 0 0;color:#1a2340;">
# Production Thinking Challenges
# </h1>
# </div>

# %% [markdown]
# 3. What is wrong with this error handling?</br>
# try:</br>
#  result = process_payment(order)</br>
# except:</br>
#  pass</br>
# **answer:The error handling is wrong because it uses a bare except, which catches all exceptions and hides errors.</br>
#             This makes debugging difficult and can hide serious issues. It’s better to catch specific exceptions and log them.**

# %% [markdown]
# 4. A function calls an external API to get exchange rates. What reliability measures should you add?</br>
# **answer:For an external API, you should add timeouts, retries ackoff, proper exception handling, caching/fallback data, rate-limit handling, and logging/monitoring to make the system reliable.**

# %% [markdown]
# <div style="background:#eef0f8;padding:15px 20px;border-left:6px solid #4a5cff;">
# <p style="margin:0;color:#4a5cff;font-size:12px;font-weight:bold;letter-spacing:4px;">
# SECTION 11
# </p>
#
# <h1 style="margin:8px 0 0 0;color:#1a2340;">
# Code Improvement Practices
# </h1>
# </div>

# %%
# IMPROVE-1: Refactor for readability, efficiency, and edge case handling
# Problems to fix:
# 1. No docstring / type hints
# 2. Bad variable names (l looks like 1)
# 3. r = r + [item] is O(n²) — should use append or comprehension
# 4. range(0, len(l)) — antipattern, just iterate directly
# 5. No edge case handling (None input, non-numeric items)
# Your improved version:
def process_numbers(numbers):
    if not numbers:
        return []

    result = []

    for num in numbers:
        if isinstance(num, (int, float)) and num > 0:
            result.append(num * 2)

    return result


# TEST RUN (this is required)
print(process_numbers([1, -2, 3, 4, "a", 0]))
# Out:
# [2, 6, 8]

# %% [markdown]
# <div style="background:#eef0f8;padding:15px 20px;border-left:6px solid #4a5cff;">
# <p style="margin:0;color:#4a5cff;font-size:12px;font-weight:bold;letter-spacing:4px;">
# SECTION 14
# </p>
#
# <h1 style="margin:8px 0 0 0;color:#1a2340;">
# Mini Case Study
# </h1>
# </div>

# %% [markdown]
# Phase 1: Analyze Requirements
#
# 1. *Core Operations Needed*
#
#  Validate student data
# - Calculate course progress
# - Generate student reports
# - Generate platform summary
#
# *Validations Required*
#
# - Student ID should exist
# - Name should not be empty
# - Completed lessons ≤ total lessons
# - Quiz scores should be valid
# - Subscription should be basic or premium
#
# *Output Formats Needed*
#
# - Validation result (True/False)
# - Course progress report (dict)
# - Student report (dict)
# - Platform summary (dict)

# %% [markdown]
# Phase 2: Identify Edge Cases
# *List at least 8 edge cases that your i*
#
# - Empty student name
# - Missing student ID
# - No courses enrolled
# - Total lessons = 0
# - Completed lessons > total lessons
# - Empty quiz scores list
# - Invalid subscription type
# - Quiz scores outside 0–100 range

# %% [markdown]
# <div style="background:#eef0f8;padding:15px 20px;border-left:6px solid #4a5cff;">
# <p style="margin:0;color:#4a5cff;font-size:12px;font-weight:bold;letter-spacing:4px;">
# SECTION 17
# </p>
#
# <h1 style="margin:8px 0 0 0;color:#1a2340;">
# Self Assesment Checklist
# </h1>
# </div>

# %% [markdown]
# **Concept Understanding**

# %% [markdown]
# 🟩I can explain the difference between = , == , and is with examples</br>
# 🟩I understand why 0.1 + 0.2 != 0.3 and know the correct fix</br>
# 🟩I can describe Python's type system: dynamic typing, objects, references</br>
# 🟩I understand truthiness and can list all falsy values</br>
# 🟨I understand LEGB scope and can predict what value a variable lookup returns</br>
# 🔴I understand mutable default arguments and why they are bugs</br>
# 🔴I understand closure late-binding and how to fix it</br>
# 🟩I understand and / or returning operands, not booleans</br>
# </br>
# *Coding Confidence*</br>
# </br>
# I can write functions with *args , **kwargs , and keyword-only arguments</br>
# 🟩I can write list, dict, and generator comprehensions</br>
# 🟩I can use for-else correctly</br>
# 🔴I can write and apply a decorator with functools.wraps</br>
# 🔴I can write a generator function with yield</br>
# 🔴I can use the walrus operator := correctly</br>
# 🟨I can format strings with f-strings including format specs</br>
# </br>
# *Debugging Ability*</br>
# </br>
# 🟩I can spot the difference between = and == in buggy code</br>
# 🟩I can identify and fix the mutable default argument bug</br>
# 🟨I can debug the closure late-binding problem</br>
# 🟨I can identify why modifying a list during iteration skips elements</br>
# 🟨I understand UnboundLocalError and its cause</br>
# </br>
# *Problem-Solving Skills*</br>
# </br>
# 🔴I approach problems by designing the interface before implementation</br>
# 🟩I identify edge cases before writing code</br>
# 🟩I can refactor working code for readability and efficiency</br>
# 🔴I think about time and space complexity before choosing an approach</br>
# </br>
# *Interview Readiness*</br>
# </br>
# 🔴I can explain any concept from this session without notes</br>
# 🟩I can write a memoization decorator in a live interview</br>
# 🟨I can explain why float equality fails in a financial system</br>
# 🟨I can implement FizzBuzz in multiple ways (loop, comprehension, generator)</br>

# %% [markdown]
# <div style="background:#eef0f8;padding:15px 20px;border-left:6px solid #4a5cff;">
# <p style="margin:0;color:#4a5cff;font-size:12px;font-weight:bold;letter-spacing:4px;">
# SECTION 18
# </p>
#
# <h1 style="margin:8px 0 0 0;color:#1a2340;">
# Reflection Section
# </h1>
# </div>

# %% [markdown]
# 1. What did I learn today that I didn't know before?</br>
# **answer : I learned about mutable default arguments, closure late-binding, LEGB scope, and how to improve code readability and efficiency.** </br>
# </br>
# 2. Which concept confused me the most? What specifically was unclear?</br>
# **answer :Closure late-binding confused me the most because it was difficult to understand how variables are captured and evaluated later in closures.** </br>
# </br>
# 4. Which debugging challenge took me longest? Why?</br>
# **answer :The mutable default argument bug took the longest because the code appeared correct but produced unexpected results across multiple function calls.** </br>
# </br>
# 6. What would I do differently if I redid this practice sheet?</br>
# **answer :I would spend more time analyzing edge cases before coding and test my solutions more thoroughly**.</br>
# </br>
